# %%
from MSSMHiggs import main
import matplotlib.pyplot as plt
from time import time

pathplot = '/home/lukas/Schreibtisch/SModelS/code/checks/plots/'
color = ['red','blue','green','darkred','orange','cyan']
ls = ['-','--','-.',':']
hig = ['h','H','A']
higgsnumb = [11,12,21]
fontsize = 12
legfontsize = 10

num_x_global = 100

# %%
list_element = [ [[2,12],[3,0]] , [[3,20.]] , [[25,20]] ]
list_block = ['SUSHI','MINPAR','EXTPAR']
t = time()
main(list_element, list_block)
t = time() - t
t
# Out:
# 3.3623626232147217

# %%
import os, subprocess
import parameter as para
import SusyHit
True in [len(SusyHit.get_BR_list_PDG(item))==0 for item in [1000022, 1000023, 1000025, 1000035, 1000024, 1000037, 25, 35, 36]]
# Out:
# [[[0.126143228, [1000012, -12]],
#   [0.126143228, [-1000012, 12]],
#   [0.126143228, [1000014, -14]],
#   [0.126143228, [-1000014, 14]],
#   [0.126143228, [1000016, -16]],
#   [0.126143228, [-1000016, 16]],
#   [0.120694191, [1000015, -15]],
#   [0.120694191, [-1000015, 15]],
#   [0.000419341565, [1000011, -11]],
#   [0.000419341565, [-1000011, 11]],
#   [0.000419341565, [1000013, -13]],
#   [0.000419341565, [-1000013, 13]],
#   [1.87204584e-05, [2000011, -11]],
#   [1.87204584e-05, [-2000011, 11]],
#   [1.87204584e-05, [2000013, -13]],
#   [1.87204584e-05, [-2000013, 13]]],
#  [[0.110360465, [1000015, -15]],
#   [0.110360465, [-1000015, 15]],
#   [0.0859911812, [1000012, -12]],
#   [0.0859911812, [-1000012, 12]],
#   [0.0859911812, [1000014, -14]],
#   [0.0859911812, [-1000014, 14]],
#   [0.0859911812, [1000016, -16]],
#   [0.0859911812, [-1000016, 16]],
#   [0.0831785983, [2000015, -15]],
#   [0.0831785983, [-2000015, 15]],
#   [0.0206223815, [1000011, -11]],
# ...

# %%
from classSusyHit import SusyHit
from MSSMHiggs import initiate

list_element = [ [[2,12],[3,0]] , [[3,20.]] , [[25,20]] ]
list_block = ['SUSHI','MINPAR','EXTPAR']
initiate(list_element, list_block)

a = SusyHit()
del a

# %%
b = SusyHit()
del b
c = SusyHit()

# %%
c()

# %%
c.get_BR_list_Susy()
# Out:
# [[0.158764259, [1000024, -1000024]],
#  [0.116807848, [1000024, -1000037]],
#  [0.116807848, [1000037, -1000024]],
#  [0.0791435658, [1000023, 1000025]],
#  [0.0597142647, [1000022, 1000022]],
#  [0.0203922187, [1000022, 1000025]],
#  [0.0200988307, [1000022, 1000023]],
#  [0.0166706673, [1000037, -1000037]],
#  [0.0106425159, [1000023, 1000035]],
#  [0.0100659606, [1000025, 1000025]],
#  [0.00590635633, [1000023, 1000023]],
#  [0.00338361537, [1000022, 1000035]],
#  [5.86543681e-05, [1000001, -1000001]],
#  [5.86543681e-05, [1000003, -1000003]],
#  [4.17520542e-05, [1000002, -1000002]],
#  [4.17520542e-05, [1000004, -1000004]],
#  [3.09642366e-05, [1000012, -1000012]],
#  [3.09642366e-05, [1000014, -1000014]],
#  [3.09642366e-05, [1000016, -1000016]],
#  [1.36110242e-05, [2000015, -2000015]],
#  [9.43520434e-06, [1000011, -1000011]],
#  [9.43520434e-06, [1000013, -1000013]],
#  [7.14547604e-06, [2000002, -2000002]],
#  [7.14547604e-06, [2000004, -2000004]],
# ...

# %%
from classMSSMHiggs import MSSMHiggs
from time import time

list_element = []#[ [[2,12],[3,0]] , [[3,20.]] , [[25,20]] ]
list_block = []#['SUSHI','MINPAR','EXTPAR']

t = time()
a = MSSMHiggs(list_element, list_block)
a()
del a
t = time() - t
t
# Out:
# 15.813499450683594

# %%
from MSSMHiggs import main
from time import time

list_element = []# [ [[2,12],[3,0]] , [[3,20.]] , [[25,20]] ]
list_block = []# ['SUSHI','MINPAR','EXTPAR']
t = time()
main(list_element, list_block)
t = time() - t
t
# Out:
# 15.745085716247559

# %%
c = MSSMHiggs(list_element, list_block)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-e3d36c321faa> in <module>()
# ----> 1 c = MSSMHiggs(list_element, list_block)
#
# /home/lukas/Schreibtisch/SModelS/code/Higgs/classMSSMHiggs.py in __init__(self, list_element, list_block)
#      13     def __init__(self,list_element, list_block):
#      14         if MSSMHiggs.active:
# ---> 15             raise Exception('Error: classMSSMHiggs.MSSMHiggs: Only one class object can be initiated')
#      16         else:
#      17             clear_outputdir()
#
# Exception: Error: classMSSMHiggs.MSSMHiggs: Only one class object can be initiated

# %%
import FeynHiggs
import fileIO
# Block FEYNHIGGSFLAGS
#          1      4   # mssmpart
#          2      0   # fieldren
#          3      0   # tanbren
#          4      2   # higgsmix
#          5      4   # p2approx
#          6      2   # looplevel
#          7      1   # runningMT
#          8      1   # botResum
#          9      0   # tlCplxApprox
#         10      0   # loglevel

list = [[1,4],[2,0],[3,0],[4,1],[5,4],[6,0],[7,0],[8,1],[9,2],[10,0]]
fileIO.change_inputfile([],[])
FeynHiggs.create_FeynHiggs_inputfile(list)
